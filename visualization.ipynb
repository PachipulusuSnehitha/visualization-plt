# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=([1,2,3,4])
y=([5,6,7,8])
plt.plot(x,y)
plt.show()

# %%
x=(1,2,3,4)
y=(5,6,7,8)
plt.plot(x,y,color="red",linestyle="dotted",ms=5,linewidth=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
##draw a line

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints, color="orange")
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints,"+")
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints,"*")
plt.show()

# %%
plt.plot(ypoints,marker="X")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints,marker="*",ms=20,color="pink")
plt.show()

# %%
##  mec=marked edge color, can be used to color the edges of the marker

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints, marker="*",ms=10,mec="black")
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints, marker="*", ms=30,mec="black",mfc="pink")
plt.show()

# %%
### mfc= marked face color

# %%
ypoints= np.array([10,200])
plt.plot(ypoints, marker="o",mec="k",mfc="y",ms=20)
plt.show()

# %%
### default "x"values were '0,1,2,3,4.....'.

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints, linestyle="dotted")
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints, linestyle="dashed")
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints, linewidth=5)
plt.show()

# %%
### linewidth or lw for increasing the size of the line

# %%
y1=np.array([1,2,3,4])
y2=np.array([5,6,7,8])
plt.plot(y1)
plt.plot(y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.xlabel("marks",fontsize=10,color="orange")
plt.ylabel("points",fontsize=10,color="green")

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints)
plt.title("heights")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-9ae6d9df3b89> in <module>
#       2 ypoints= np.array([10,200])
#       3 plt.plot(xpoints,ypoints)
# ----> 4 plt.title("heights")
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
xpoints= np.array([5,100])
ypoints= np.array([10,200])
plt.plot(xpoints,ypoints)
plt.grid(color="green")
plt.show()

# %%
### You can use the axis parameter in the grid() function to specify which grid lines to display.

### Legal values are: 'x', 'y', and 'both'. Default value is 'both'

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])


plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8,1,10])

plt.bar(x,y)
plt.show()

# %%
### If you want the bars to be displayed horizontally instead of vertically, use the barh() function.
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3,2,9, 10])

plt.bar(x, y, color = "violet")
plt.show()

# %%
## The barh() takes the keyword argument height to set the height of the bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 9, 10])

plt.barh(x, y,height=0.5)
plt.show()

# %%
y = np.array([10,20,30,40,50])

plt.pie(y)
plt.show()

# %%
### Add labels to the pie chart with the label parameter.

### The label parameter must be an array with one label for each wedge

# %%
y = np.array([18, 25,15,10])
mylabels = ["Cherries","Apples", "Bananas","Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
### As mentioned the default start angle is at the x-axis, but you can change the start angle 
### by specifying a startangle parameter.

### The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
y = np.array([18, 25,15,10])
mylabels = ["Cherries","Apples", "Bananas","Dates"]

plt.pie(y, labels = mylabels,startangle=100)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0,0.95, 0.1, 3.2]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
